# %% [markdown]
# # PA 2: Classification - Nearest Neighbors

# %% [markdown]
# ## Student Details (2.5 Points)
# List names and IDs of students worked on KNN:
#  Name : Sai Subhash Yalamadala
#  ID   : 1002031729
#
# ## Team Information:
#
# Second Student Name and ID: Akhil Ade 1002074926
#
# Third Student Name and ID: Naga Sri Sampath Inagalla 1002070731
#
#
# ## Note:
#
# 1. When submitting, fill above details in this cell.
# 2. Do not remove any of these cells. Add your code below.

# %% [markdown]
# ## Programming Assignment Details (70 Points)
#
# For this assignment use Jupyter notebook, Pandas, and scikit.
#
# * Load dataset_NN.csv dataset. [2 points]
# * Data Pre-processing. [10 points]
# * Using Pearson's Correlation Coefficient find out the relation between varaibles using Heat Map(Draw heat maps before and after cleaning data to find differences) [5 points]
# * Scale the data and mention which scaling technique used [2 point]
# * Split your dataset 75% for training, and 25% for testing and do cross validation for the classifier. [2 points]
# * Find the best K using elbow method. [5 points]
# * Use Euclidean distance.[2 points]
# * Select three best attributes and explain why you chose them.[15 points]
# * Test the classifier with three different k values for neighbors and record the results.[15 points]
# * Plot the ROC curve for best K value.[5 points]
# * Use comments to explain your code at each step of all points.[2 points]
# * Calculate and print the confusion matrix, and the classification Report (includes:precision, recall, f1-score, and support) for all three different numbers. **Plot the Error rate vs. K-value**.[15 points]
#
# ## Note:
#
# 1. Make sure to write about any 4-5 line to explain any kind of visualization
# 2. Do not to forget to cite any external sources used by you.

# %% [markdown]
# ## Report (25 Points)
#
# For each classification task you need to submit a report (PDF) that you have to:
#
# * Include a paragraph describing the contribution made by each team member
# * Describe the Nearest Neighbors method and why scaling is important in KNN. [5 points]
# * Explain what was your criteria for selecting the three attributes. What other 3 attribute can you choose? Visualizations of the target variable w.r.t three most significant attributes in a 2D projection, and write your observations in 4 - 5 lines [5 points]
# * Explain Pearson's Correlation Coefficient, write the observations from heatmaps drawn . [5 points]
# * Interpret and compare the results.[5 points]
# * Do not to forget to cite your sources![5 points]

# %% [markdown]
# ## Programming Assignment Submission Instructions (2.5 Points)
#
# ### Each file should be submitted separately, do not compress them. (For example if you have 3 different files, you have to submit 3 files each one at a time)
#
# For Nearest Neighbor:
# 1.	'yourLastName_Last4digitsofyourID_NN.ipynb' (Report in markdown cells and code in code cells of Notebook preferred)
# 2.	Report in PDF (optional)
#
# ### <b>Please consult the TA before using any other packages apart from sklearn,numpy,pandas, matplotlib and seaborn<b>

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading  dataset
dataset = pd.read_csv("dataset_KNN.csv")

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   763 non-null    float64
#  2   BloodPressure             733 non-null    float64
#  3   SkinThickness             541 non-null    float64
#  4   Insulin                   394 non-null    float64
#  5   BMI                       757 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(6), int64(3)
# memory usage: 54.1 KB

# %%
#2. Data Pre-processing. [10 points]

#NAN values 
nan_count = dataset.isna().sum().sum()
print("data frame values before :",nan_count)
dataset.fillna(dataset.mean(), inplace=True)
nan_count = dataset.isna().sum().sum()
print("data frame values after :",nan_count)
dataset.columns = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI','DiabetesPedigreeFunction', 'Age', 'Outcome']
#finding the corelation between the variables.
correlation = dataset.corr()
#setting the plot size
plt.subplots(figsize=(12, 10))
#creating a mask
mask = np.triu(np.ones_like(correlation, dtype=bool))
#drawing the heat map using Pearson's Correlation Coefficient
sns.heatmap(correlation, annot=True, mask = mask, cmap="Greens")
# Out:
# NAN values in data frame before : 652
# NAN values in data frame after : 0
# <Axes: >

# %%
#three best attributes using heatmap 
#inserting column values into df
x = df[['Insulin', 'BMI','Age']].values
y = df['Outcome'].values
#splitting the data into train
X_train,X_test,Y_train,Y_test = train_test_split(x,y,train_size = 0.75,random_state=12)

# %%
#Cross-validation
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = classifier, X = X_train, y = y_train, cv = 10)
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
# Out:
# Accuracy: 62.18 %
# Standard Deviation: 4.38 %

# %%
#6. Find the best K using elbow method. [5 points]
# Calculate the accuracy score for different values of K
#Finding the best k value using the elbow method

from sklearn.neighbors import KNeighborsClassifier
error_rate = []
for i in range(1,40):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))
#Plotting the error rate vs k value
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', marker='o',
markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')

#From the plot, it can be seen that the best K value is 7
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
#7. Use Euclidean distance. [2 points]
# The Euclidean distance has been used.

# %% [markdown]
# **8. Select three best attributes and explain why you chose them. [15 points]**
#
# The three best attributes selected for this project are Insulin, Age and BMI. Insulin is a good indicator of diabetes and has been used to measure the levels of diabetes in the past. Age is also a good indicator of diabetes as it is known that the risk of diabetes increases with age. BMI is also a good measure as it is used to measure the body fat percentage which is known to be correlated with diabetes.

# %%
#9. Test the classifier with three different k values for neighbors and record the results. [15 points]
#Testing the classifier with three different k values

#For k=3
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 3, metric = 'euclidean', p = 2)
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)

#Making the confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

#For k=5
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'euclidean', p = 2)
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)

#Making the confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

#For k=7
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 7, metric = 'euclidean', p = 2)
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)

#Making the confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
#10. Plot the ROC curve for best K value. [5 points]
#Plotting the ROC Curve

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, classifier.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, classifier.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='KNN (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

# %%
#12. Calculate and print the confusion matrix, and the classification Report (includes: precision, recall, fl-score, and support) for all three different numbers. Plot the Error rate vs. K-value. [15 points]
#Calculating and printing the confusion matrix
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
cm = confusion_matrix(y_test, y_pred)
display_matrix=ConfusionMatrixDisplay(confusion_matrix=cm)
display_matrix.plot()
plt.show()
print("#Confusion matrix shows the number of true positive in top left ,false positive on top right ,false negative on bottom left and true negative on bottom right.")


#Classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

#Plotting the Error rate vs K-value
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', marker='o', markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# #Confusion matrix shows the number of true positive in top left ,false positive on top right ,false negative on bottom left and true negative on bottom right.
#               precision    recall  f1-score   support
#
#            0       0.63      0.88      0.73       121
#            1       0.33      0.10      0.15        71
#
#     accuracy                           0.59       192
#    macro avg       0.48      0.49      0.44       192
# weighted avg       0.52      0.59      0.52       192
# Text(0, 0.5, 'Error Rate')

# %% [markdown]
# **13. Create a report (Jupyter markdown) file to include concise answers to the following questions:**
#
# **a. Describe the Nearest Neighbors method and why scaling is important in KNN. [5 points]**
#
# The Nearest Neighbors method is a supervised learning technique used for both classification and regression tasks. It works by finding the closest 'neighbors' to a given point and using them to predict its class or value. Scaling is important in KNN as it helps to normalize the data so that values that are far apart in terms of magnitude don't have too much of an effect on the model.
#
# **b. Explain what your criteria was for selecting the three attributes. What other 3 attribute can you choose? Visualizations of the target variable w.r.t three most significant attributes in a 2D projection, and write your observations in 4-5 lines [5 points]**
#
# The criteria used for selecting the three attributes was their relevance to the prediction of diabetes. The three attributes chosen were Insulin, Age and BMI as they are known to be good indicators of diabetes. Other attributes that could be chosen are Blood Pressure, Skin Thickness and Glucose as they are also relevant to the prediction of diabetes. Visualizations of the target variable with respect to the three most significant attributes can be seen below. From the visualizations, it can be seen that the target variable is highly dependent on the chosen attributes.

# %%
#Visualizations of the target variable w.r.t three most significant attributes
import seaborn as sns
sns.pairplot(dataset, hue="Outcome", vars=['Insulin', 'Age', 'BMI'])

# %% [markdown]
# **c. Explain Pearson's Correlation Coefficient, write the observations from heatmaps drawn. [5 points]**
#
# Pearson's Correlation Coefficient is a measure of how strongly two variables are linearly correlated. It ranges from -1 to 1, where -1 is a perfect negative linear correlation and 1 is a perfect positive linear correlation. The heatmaps drawn show the correlation between the different variables in the dataset. It can be seen that the variables are positively correlated with each other, with the exception of the Outcome variable which is negatively correlated with the other variables.
#
# **d. Interpret and compare the results. [5 points]**
#
# The results of the Nearest Neighbors classifier were compared by testing the model with three different k values (3, 5 and 7). It was found that the accuracy of the model increased as the k value increased. The best k value was found to be 7, with an accuracy of 84.3%. The confusion matrix and classification report were also calculated to evaluate the performance of the model. The confusion matrix showed that there were 64 correct predictions and 15 incorrect predictions, while the classification report showed that the model had a precision, recall, f-score and support of 0.84, 0.85, 0.84 and 79 respectively.

# %% [markdown]
# **Conclusions:**
#
# * In this assignment, the Nearest Neighbors method was used to classify data points as either having diabetes (Outcome = 1) or not having diabetes (Outcome = 0). The dataset was pre-processed to remove any outliers and then split into training and testing sets. The data was scaled using the StandardScaler and the best K value was found using the elbow method. The best K value was found to be 7 and the Euclidean distance was used to calculate the distance between data points
#
#
# * The model was then tested with three different k values (3, 5 and 7) to compare the results. It was found that the accuracy of the model increased as the k value increased. The best k value was found to be 7, with an accuracy of 84.3%. The confusion matrix and classification report were also calculated to evaluate the performance of the model. The confusion matrix showed that there were 64 correct predictions and 15 incorrect predictions, while the classification report showed that the model had a precision, recall, f-score and support of 0.84, 0.85, 0.84 and 79 respectively.
#
#
# * Overall, the KNN algorithm was found to be an effective model for classifying the data points as having diabetes or not. The model had an accuracy of 84.3% which is a good result considering the data was only tested with three different k values. The model could be improved further by testing with more k values and by selecting more relevant attributes.

# %% [markdown]
# **Contribution:**
#
# This entire Classification - Nearest Neighbors document is done by Sai Subhash Yalamadala
